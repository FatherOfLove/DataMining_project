# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from pandas import read_csv as r_c
from sklearn.utils import resample as RS
from sklearn.model_selection import train_test_split as TTS
from sklearn.linear_model import LogisticRegression as LR 
from sklearn.metrics import accuracy_score as a_s
from sklearn.metrics import confusion_matrix as c_m
from sklearn.metrics import classification_report as c_r

# %%
data_lst=r_c('/Users/jiezou/Documents/GitHub/DataMining_project/listings.csv')
data_lst.shape
#data_lst.isnull().sum()
# Out:
# (7833, 106)

# %%
#data_lst.dtypes

# %%
#drop the data 'city' is N/A
data_lst_1= data_lst.dropna(subset=['city'])
data_lst_1.to_csv('data_lst_1.csv',index=0)
data_lst_1.shape
# Out:
# (7823, 106)

# %%
data_lst_1.city.describe()
# Out:
# count              7823
# unique                9
# top       San Francisco
# freq               7781
# Name: city, dtype: object

# %%
#keep the data 'city'contains'San Francisco'
data_lst_sf=data_lst_1[data_lst_1['city'].str.contains('San Francisco')]
data_lst_sf.to_csv('data_lst_sf.csv',index=0)
data_lst_sf.shape
# Out:
# (7787, 106)

# %%
#remove the red columns
data_lst_cutc= data_lst_sf.drop(['listing_url','scrape_id','last_scraped','experiences_offered','thumbnail_url','medium_url','picture_url','xl_picture_url','host_url','host_name','host_location','host_acceptance_rate','host_thumbnail_url','host_picture_url','host_neighbourhood','host_listings_count','street','neighbourhood_group_cleansed','market','smart_location','country_code','country','latitude','longitude','is_location_exact','square_feet','guests_included','extra_people','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','calendar_updated','has_availability','availability_30','availability_60','availability_90','availability_365','calendar_last_scraped','number_of_reviews_ltm','first_review','last_review','review_scores_accuracy','requires_license','license','jurisdiction_names','is_business_travel_ready','require_guest_profile_picture','require_guest_phone_verification','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','reviews_per_month'],1)
data_lst_cutc.to_csv('data_lst_cutc.csv',index=0)
data_lst_cutc.shape
# Out:
# (7787, 50)

# %%
data_lst_cutc.head()
# Out:
#      id                                               name  \
# 0   958                Bright, Modern Garden Unit - 1BR/1B
# 1  3850                              Charming room for two
# 2  5858                                 Creative Sanctuary
# 3  7918         A Friendly Room - UCSF/USF - San Francisco
# 4  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
#
#                                              summary  \
# 0  New update: the house next door is under const...
# 1  Your own private room plus access to a shared ...
# 2                                                NaN
# 3  Nice and good public transportation.  7 minute...
# 4  Nice and good public transportation.  7 minute...
#
#                                                space  \
# 0  Newly remodeled, modern, and bright garden uni...
# 1  This is the first room I rented on Airbnb, sta...
# 2  We live in a large Victorian house on a quiet ...
# 3  Room rental-sunny view room/sink/Wi Fi (inner ...
# 4  Room rental Sunny view Rm/Wi-Fi/TV/sink/large ...
#
#                                          description  \
# 0  New update: the house next door is under const...
# 1  Your own private room plus access to a shared ...
# 2  We live in a large Victorian house on a quiet ...
# 3  Nice and good public transportation.  7 minute...
# 4  Nice and good public transportation.  7 minute...
#
#                                neighborhood_overview  \
# 0  *Quiet cul de sac in friendly neighborhood *St...
# 1  This is a quiet, safe neighborhood on a substa...
# 2  I love how our neighborhood feels quiet but is...
# 3  Shopping old town, restaurants, McDonald, Whol...
# 4                                                NaN
#
#                                                notes  \
# 0  Due to the fact that we have children and a do...
# 1  Here is the complete list of House Rules you a...
# 2  All the furniture in the house was handmade so...
# 3  Please email your picture id with print name (...
# 4  Please email your picture id with print name (...
#
#                                              transit  \
# 0  *Public Transportation is 1/2 block away.  *Ce...
# 1  Public transit service to my house is outstand...
# 2  The train is two blocks away and you can stop ...
# 3         N Juda Muni and bus stop.  Street parking.
# 4  N Juda Muni, Bus and UCSF Shuttle. small shopp...
#
#                                               access  \
# 0  *Full access to patio and backyard (shared wit...
# 1  During the hours of 7:00 to 22:00, your access...
# 2  Our deck, garden, gourmet kitchen and extensiv...
# 3                                                NaN
# 4                                                NaN
#
#                                          interaction  ... maximum_nights  \
# 0  A family of 4 lives upstairs with their dog. N...  ...             30
# 1  I live at the house in my own bedroom, and I w...  ...              5
# 2                                                NaN  ...             60
# 3                                                NaN  ...             60
# 4                                                NaN  ...             90
#
#    number_of_reviews review_scores_rating review_scores_cleanliness  \
# 0                199                 97.0                      10.0
# 1                136                 94.0                       9.0
# 2                111                 98.0                      10.0
# 3                 17                 85.0                       8.0
# 4                  8                 93.0                       9.0
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  10.0                        10.0                   10.0
# 1                  10.0                        10.0                    9.0
# 2                  10.0                        10.0                   10.0
# 3                   9.0                         9.0                    9.0
# 4                  10.0                        10.0                    9.0
#
#    review_scores_value instant_bookable          cancellation_policy
# 0                  9.0                t                     moderate
# 1                  9.0                f  strict_14_with_grace_period
# 2                  9.0                f  strict_14_with_grace_period
# 3                  8.0                f  strict_14_with_grace_period
# 4                  9.0                f  strict_14_with_grace_period
#
# [5 rows x 50 columns]

# %%
data_lst_cutc.tail()
# Out:
#             id                                               name  \
# 7828  37460323     5 bedroom house by beach, clean and convenient
# 7829  37467170  2 bedrooms/1 bath private guest suite w/st.par...
# 7830  37469573  One of a Kind San Francisco Victorian- Turret ...
# 7831  37489792                       San Francisco 1B1B Apartment
# 7832  37497197                   Nice private bedroom has parking
#
#                                                 summary  \
# 7828  Renovated 5 bedroom, 3 bath home with garage p...
# 7829  Comfortable and relaxing 2 bedroom and 1 bath ...
# 7830  Step back in time in my San Francisco victoria...
# 7831                                                NaN
# 7832  Charming 2 bedrooms 1 bath flat has a shared k...
#
#                                                   space  \
# 7828  Main floor has 3 bedrooms, 2 bathrooms, kitche...
# 7829  *There is free parking in front of home for gu...
# 7830  65 steps up into your own private space within...
# 7831                                                NaN
# 7832  This charming flat has 2 bedrooms, 1 bath, kit...
#
#                                             description  \
# 7828  Renovated 5 bedroom, 3 bath home with garage p...
# 7829  Comfortable and relaxing 2 bedroom and 1 bath ...
# 7830  Step back in time in my San Francisco victoria...
# 7831                                                NaN
# 7832  Charming 2 bedrooms 1 bath flat has a shared k...
#
#                                   neighborhood_overview  \
# 7828                                                NaN
# 7829  *Quiet and peaceful neighborhood for visiting SF.
# 7830  Sitting just across the street from The Panhan...
# 7831                                                NaN
# 7832                                                NaN
#
#                                                   notes  \
# 7828                                                NaN
# 7829                                                NaN
# 7830  - I have 3 dogs (2 Great Danes and a Lab). Whi...
# 7831                                                NaN
# 7832                                                NaN
#
#                                                 transit  \
# 7828                                                NaN
# 7829  *Minutes to Interstate 280 and Highway 101 *SF...
# 7830  The best way to get around town is via Uber/ L...
# 7831                                                NaN
# 7832                                                NaN
#
#                                                  access  \
# 7828                                                NaN
# 7829                                                NaN
# 7830  Guests will have their own private and keyless...
# 7831                                                NaN
# 7832                                                NaN
#
#                                             interaction  ... maximum_nights  \
# 7828  I am away from the property often as I travel ...  ...            180
# 7829  Host family lives upstairs of house - a quiet ...  ...             27
# 7830  While I live a private part of the house (sepa...  ...             14
# 7831                                                NaN  ...           1125
# 7832                                                NaN  ...           1125
#
#       number_of_reviews review_scores_rating review_scores_cleanliness  \
# 7828                  0                  NaN                       NaN
# 7829                  0                  NaN                       NaN
# 7830                  0                  NaN                       NaN
# 7831                  0                  NaN                       NaN
# 7832                  0                  NaN                       NaN
#
#      review_scores_checkin review_scores_communication review_scores_location  \
# 7828                   NaN                         NaN                    NaN
# 7829                   NaN                         NaN                    NaN
# 7830                   NaN                         NaN                    NaN
# 7831                   NaN                         NaN                    NaN
# 7832                   NaN                         NaN                    NaN
#
#       review_scores_value instant_bookable          cancellation_policy
# 7828                  NaN                t  strict_14_with_grace_period
# 7829                  NaN                f                     moderate
# 7830                  NaN                f                     moderate
# 7831                  NaN                f  strict_14_with_grace_period
# 7832                  NaN                f  strict_14_with_grace_period
#
# [5 rows x 50 columns]
